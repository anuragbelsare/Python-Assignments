# %%
1.What are the two values of the Boolean data type? How do you write them?

        True and False are the two values of Boolean data type
    
        a=True (T in Upper Case and other letters in lower case)
        b=False (F in Upper Case and other letters in lower case)
        
2. What are the three different types of Boolean operators?

           Comparison Operators --> <,>,==  evaluate the expression (a>30) returns True or False
    
           Boolean operators  --> and ,or 
                                  Boolean and operator returns True if both operands returns true else retuens False.
                                  a<300 and a>200
                                     
                                  Boolean or operator returns true either one of the operands returns True.
                                  returns False if both operands are false
                                  a<300 or a>200 
                                    
           Not operator -->     The not operator returns True if its operand is a false expression and returns False if it is true.
                                  eg:
                                  a=100
                                  not(a>10) returns True
        
        


3. Make a list of each Boolean operator's truth tables
     (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
    
    A = a>30,B = a<50
    
     Truth table  >>> and
     A        B     A and B(returns)
     True    True   True
     True    False   False
     False    True   False
     False    False   False
    
     Truth table  >>> or
     A        B     A or B(returns)
     True    True   True
     True    False   True
     False    True   True
     False    False   False
    
    Truth table  >>> not
      A             not A (returns)
     True           False
     False          True
                 
  
4. What are the values of the following expressions?
(5 > 4) and (3 == 5)   ---> False
 not (5 > 4)           ----> False
(5 > 4) or (3 == 5)    ---> True
not ((5 > 4) or (3 == 5))  ---> False
(True and True) and (True == False)  ---->False
(not False) or (not True) --->True


5. What are the six comparison operators?

    <  less than
    <=   less than or equal to
    >   greater than
    >=  greater than or equal to
    ==  equal to
    !=  not equal to
    
    
6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
   =  It is an assignment operator.
      It is used for assigning the value to a variable.
        
   == (equal to) It is a relational or comparison operator.
       It is used for comparing two values.
  
      
7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

spam = 0
# first block
if spam == 10:
print('eggs')
# second block
if spam > 5:
print('bacon')
# third block
else:
print('ham')
print('spam')
print('spam')


8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam,
   and prints Greetings! if anything else is stored in spam.
    
    spam = 3
if spam == 1:
 print('Hello')
elif spam == 2:
 print('Howdy')
else:
 print('Greetings!')


9.If your programme is stuck in an endless loop, what keys you’ll press?
  CTRL + C


10. How can you tell the difference between break and continue?
        break statement stops the loop in which the statement is placed.
        continue statement skips a single iteration in a loop.

11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

start: (optional) The start index is an integer, and if not given, the default value is 0.
stop:  The stop index decides the value at which the range function has to stop. It is a mandatory input to range function. 
       The last value will be always 1 less than the stop value.
step: (optional).The step value is the number by which the next number is range has to be incremented, by default, it is 1.
    
          The range(10) function,#range(stop)
              no of counts is mentioned,by default it starts from 0 index,incremented by 1
              the loop will be executed till it range reached the value 10
                
        range(0, 10)  function, #range(start, stop)
              no of counts is mentioned as 10 ,
              index start number is defined as 0,
              incremented by 1 by default
              the loop will be executed till it range reached the value 10
                
        range(0, 10, 1)    #range(start, stop, step) 
              no of counts is mentioned as 10 ,
              index start number is defined as 0,
              increment is defined as 1
              the loop will be executed till it range reached the value 10
                
                All the three will have the same output.
    

12. Write a short program that prints the numbers 1 to 10 using a for loop. 
Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# for loop
for i in range(1,11) :
    print(i)
# while loop
i = 1
while(i<=10):
    print(i)
    i += 1 
    
    
13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

   spam.bacon()
